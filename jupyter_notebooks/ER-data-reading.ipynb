# %%
import pandas as pd

# %%
xls = pd.ExcelFile("data/main-nacrs-emergency-department-visits-length-of-stay-2021-data-tables-en.xlsx")
xls.sheet_names
# Out:
# ['ED Visits, 2021–2022',
#  'Notes to readers',
#  'Table of contents',
#  '1 Coverage',
#  '2 LOS by PT ',
#  '3 LOS by CTAS and admitted',
#  '4 Visits and LOS by peer hosp',
#  '5 Visits and LOS by age grp ',
#  '6 Top 10 main problems',
#  '7 5-year trend — Admit LOS',
#  '8 LOS by month ',
#  '9 Age breakdown — Admit LOS']

# %%
df = pd.read_excel("data/main-nacrs-emergency-department-visits-length-of-stay-2021-data-tables-en.xlsx", xls.sheet_names[7])
df.head(20)
# Out:
#    Screen reader users: There is 1 table on this tab, called Table 5: Number of ED visits and length of stay (LOS) in ED by age group, participating provinces/territories, NACRS, 2021–2022. It begins at cell A5 and ends at cell J45. The notes begin in cell A46, coverage information begins in cell A51 and the source begins in cell A53. A link back to the table of contents is in cell A2.  \
# 0                       Back to the Table of contents
# 1   Table 5  Number of ED visits and length of sta...
# 2                                                 NaN
# 3                                 Province/territory†
# 4                                             P.E.I.§
# 5                                             P.E.I.§
# 6                                             P.E.I.§
# 7                                             P.E.I.§
# 8                                               N.S.§
# 9                                               N.S.§
# ...
